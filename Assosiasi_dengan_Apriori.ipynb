# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Membaca dataset
data = pd.read_csv('Automobile.csv')

# %%
# Menampilkan informasi awal tentang dataset
print(data.head())
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
# Preprocessing dataset
# Menghapus baris dengan nilai yang hilang
data = data.dropna()

# %%
# Mengubah kolom dengan tipe data string menjadi kategori
string_columns = data.select_dtypes(include=['object']).columns
data[string_columns] = data[string_columns].astype('category')

# %%
# Mengubah kategori menjadi nilai numerik
data[string_columns] = data[string_columns].apply(lambda x: x.cat.codes)

# %%
# Menerapkan algoritma Apriori untuk mencari itemset frekuensi tinggi
frequent_itemsets = apriori(data.astype(bool), min_support=0.1, use_colnames=True)

# %%
# Membangkitkan aturan asosiasi dari itemset frekuensi tinggi
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.7)

# %%
# Menampilkan aturan asosiasi
for index, rule in rules.iterrows():
    antecedents = ', '.join([str(item) for item in rule.antecedents])
    consequents = ', '.join([str(item) for item in rule.consequents])
    support = rule.support
    confidence = rule.confidence
    lift = rule.lift
    print(f"Rule: {antecedents} -> {consequents}")
    print(f"Support: {support}, Confidence: {confidence}, Lift: {lift}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, cylinders, displacement -> mpg, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, cylinders, displacement -> name, mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year, cylinders -> mpg, origin, weight, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, origin, cylinders, displacement -> name, acceleration, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, cylinders -> acceleration, model_year, weight, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, cylinders -> name, acceleration, weight, displacement
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, cylinders, displacement -> acceleration, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, cylinders, displacement -> name, acceleration, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year, cylinders -> acceleration, origin, weight, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, origin, cylinders, displacement -> acceleration, mpg, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, cylinders, displacement -> name, acceleration, mpg, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year, cylinders -> acceleration, mpg, weight, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, model_year, cylinders, displacement -> acceleration, mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, weight -> name, model_year, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, weight, displacement -> name, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg, weight -> origin, model_year, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year, weight -> name, origin, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin, weight, displacement -> name, mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, weight -> mpg, model_year, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year, weight -> name, mpg, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, weight, displacement -> mpg, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, weight, displacement -> name, mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year, weight -> mpg, origin, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, origin, weight, displacement -> name, acceleration, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, weight -> acceleration, model_year, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, weight -> name, acceleration, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, weight, displacement -> acceleration, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, weight, displacement -> name, acceleration, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year, weight -> acceleration, origin, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, origin, weight, displacement -> acceleration, mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, weight, displacement -> name, acceleration, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year, weight -> acceleration, mpg, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, model_year, weight, displacement -> acceleration, mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, displacement -> name, weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, mpg, origin -> weight, model_year, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, origin, model_year -> name, weight, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, mpg, displacement -> weight, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year, displacement -> name, weight, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg, model_year -> weight, origin, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, displacement -> weight, model_year, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year, displacement -> name, weight, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, model_year -> weight, cylinders, mpg, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, acceleration, model_year, displacement -> weight, origin, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, displacement -> acceleration, weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, displacement -> name, acceleration, weight, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, model_year -> acceleration, weight, cylinders, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, mpg, model_year, displacement -> acceleration, weight, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year, displacement -> acceleration, weight, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, weight, cylinders -> mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, mpg -> acceleration, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, origin, cylinders -> acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, displacement -> acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight, cylinders -> acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, model_year, cylinders -> acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, mpg, cylinders -> weight, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin, cylinders -> weight, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, cylinders, displacement -> weight, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, cylinders -> weight, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, cylinders -> weight, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, origin, cylinders -> weight, acceleration, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, cylinders, displacement -> weight, acceleration, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, cylinders -> weight, acceleration, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, cylinders -> weight, acceleration, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, cylinders, displacement -> weight, acceleration, mpg, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, cylinders -> weight, acceleration, mpg, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, cylinders -> weight, acceleration, mpg, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, cylinders, displacement -> weight, acceleration, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, cylinders, displacement -> weight, acceleration, mpg, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year, cylinders -> weight, acceleration, mpg, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, weight -> cylinders, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin, weight -> cylinders, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, weight, displacement -> cylinders, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, weight -> cylinders, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, weight -> cylinders, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, origin, weight -> cylinders, acceleration, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, weight, displacement -> cylinders, acceleration, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, weight -> cylinders, acceleration, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, weight -> cylinders, acceleration, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, weight, displacement -> cylinders, acceleration, mpg, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, weight -> cylinders, acceleration, mpg, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, weight -> cylinders, acceleration, mpg, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, weight, displacement -> cylinders, acceleration, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, weight, displacement -> cylinders, acceleration, mpg, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year, weight -> cylinders, acceleration, mpg, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin -> weight, cylinders, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, displacement -> weight, cylinders, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg -> weight, cylinders, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year -> weight, cylinders, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin, displacement -> weight, cylinders, mpg, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin -> weight, cylinders, mpg, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year -> weight, cylinders, mpg, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, displacement -> weight, cylinders, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, displacement -> weight, cylinders, mpg, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year -> weight, cylinders, mpg, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, origin, displacement -> weight, cylinders, acceleration, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin -> weight, cylinders, acceleration, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year -> weight, cylinders, acceleration, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, displacement -> weight, cylinders, acceleration, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, displacement -> weight, cylinders, acceleration, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year -> weight, cylinders, acceleration, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, origin, displacement -> weight, cylinders, acceleration, mpg, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, displacement -> weight, cylinders, acceleration, mpg, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year -> weight, cylinders, acceleration, mpg, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, model_year, displacement -> weight, cylinders, acceleration, mpg, origin
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders -> acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, cylinders -> weight, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, cylinders -> weight, acceleration, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, cylinders -> weight, acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, displacement -> weight, acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, cylinders -> weight, acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, cylinders -> weight, acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, weight -> cylinders, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, weight -> cylinders, acceleration, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, weight -> cylinders, acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, displacement -> cylinders, acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight -> cylinders, acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, weight -> cylinders, acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, mpg -> weight, cylinders, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin -> weight, cylinders, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, displacement -> weight, cylinders, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration -> weight, cylinders, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year -> weight, cylinders, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, origin -> weight, cylinders, acceleration, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, displacement -> weight, cylinders, acceleration, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg -> weight, cylinders, acceleration, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year -> weight, cylinders, acceleration, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, displacement -> weight, cylinders, acceleration, mpg, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin -> weight, cylinders, acceleration, mpg, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year -> weight, cylinders, acceleration, mpg, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, displacement -> weight, cylinders, acceleration, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, displacement -> weight, cylinders, acceleration, mpg, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year -> weight, cylinders, acceleration, mpg, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders -> weight, acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight -> cylinders, acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration -> cylinders, weight, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg -> cylinders, weight, acceleration, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin -> cylinders, weight, acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: displacement -> cylinders, weight, acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name -> cylinders, weight, acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year -> cylinders, weight, acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, origin, horsepower, name -> model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, origin, horsepower, model_year -> name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, origin, name, model_year -> horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, horsepower, name, model_year -> origin
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, origin, horsepower, name, model_year -> mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, mpg, origin, horsepower, name, model_year -> acceleration
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, origin, horsepower, name, model_year -> weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, origin, horsepower, name, model_year -> cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, origin, horsepower -> name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, origin, name -> model_year, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, origin, model_year -> name, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, horsepower, name -> origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, horsepower, model_year -> name, origin
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, name, model_year -> origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, origin, horsepower, name -> mpg, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, origin, horsepower, model_year -> name, mpg
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, origin, name, model_year -> mpg, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, horsepower, name, model_year -> mpg, origin
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, origin, horsepower, name -> acceleration, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, mpg, origin, horsepower, model_year -> name, acceleration
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, origin, name, model_year -> acceleration, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, mpg, horsepower, name, model_year -> acceleration, origin
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, origin, horsepower, name, model_year -> acceleration, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, origin, horsepower, name -> model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, origin, horsepower, model_year -> name, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, mpg, origin, name, model_year -> horsepower, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, horsepower, name, model_year -> origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, origin, horsepower, name, model_year -> mpg, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, mpg, origin, horsepower, name, model_year -> acceleration, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, origin, horsepower, name -> model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, origin, horsepower, model_year -> name, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, mpg, origin, name, model_year -> horsepower, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, horsepower, name, model_year -> origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, origin, horsepower, name, model_year -> mpg, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, mpg, origin, horsepower, name, model_year -> acceleration, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, origin, horsepower, name, model_year -> weight, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, origin -> name, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, horsepower -> name, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, mpg, name -> origin, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, mpg, model_year -> name, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, origin, horsepower -> name, mpg, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, origin, name -> mpg, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, origin, model_year -> name, mpg, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, horsepower, name -> mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, acceleration, horsepower, model_year -> name, mpg, origin
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, acceleration, name, model_year -> mpg, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, origin, horsepower -> name, acceleration, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, origin, name -> acceleration, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, mpg, origin, model_year -> name, acceleration, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, horsepower, name -> acceleration, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, mpg, horsepower, model_year -> name, acceleration, origin
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, cylinders, mpg, name, model_year -> acceleration, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, origin, horsepower, name -> acceleration, mpg, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, origin, horsepower, model_year -> name, acceleration, mpg
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, cylinders, origin, name, model_year -> acceleration, mpg, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, cylinders, horsepower, name, model_year -> acceleration, mpg, origin
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, mpg, origin, horsepower -> name, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, mpg, origin, name -> horsepower, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, origin, model_year -> name, horsepower, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, mpg, horsepower, name -> origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, mpg, horsepower, model_year -> name, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: cylinders, acceleration, mpg, name, model_year -> horsepower, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, origin, horsepower, name -> mpg, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, origin, horsepower, model_year -> name, mpg, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, acceleration, origin, name, model_year -> horsepower, mpg, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, acceleration, horsepower, name, model_year -> mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, mpg, origin, horsepower, name -> acceleration, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, mpg, origin, horsepower, model_year -> name, acceleration, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: cylinders, mpg, origin, name, model_year -> acceleration, horsepower, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: cylinders, mpg, horsepower, name, model_year -> acceleration, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders, origin, horsepower, name, model_year -> acceleration, mpg, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, origin, horsepower -> name, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, mpg, origin, name -> horsepower, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, mpg, origin, model_year -> name, horsepower, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, mpg, horsepower, name -> origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, mpg, horsepower, model_year -> name, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, acceleration, mpg, name, model_year -> horsepower, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, origin, horsepower, name -> mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, origin, horsepower, model_year -> name, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, acceleration, origin, name, model_year -> horsepower, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, acceleration, horsepower, name, model_year -> mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, mpg, origin, horsepower, name -> acceleration, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, mpg, origin, horsepower, model_year -> name, acceleration, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: weight, mpg, origin, name, model_year -> acceleration, horsepower, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, mpg, horsepower, name, model_year -> acceleration, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, origin, horsepower, name, model_year -> acceleration, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, origin, horsepower, name -> weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, origin, horsepower, model_year -> name, weight, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, name, model_year -> horsepower, weight, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, horsepower, name, model_year -> weight, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, origin, horsepower, name, model_year -> weight, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, horsepower, name, model_year -> acceleration, weight, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, weight, cylinders, mpg -> name, origin, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, weight, origin, cylinders -> name, mpg, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, weight, horsepower, cylinders -> name, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, weight, cylinders -> mpg, origin, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, weight, model_year, cylinders -> name, mpg, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, origin, cylinders, mpg -> name, acceleration, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower, weight, cylinders, mpg -> name, acceleration, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight, cylinders, mpg -> acceleration, origin, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, model_year, cylinders, mpg -> name, acceleration, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: horsepower, weight, origin, cylinders -> name, acceleration, mpg, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, weight, origin, cylinders -> acceleration, mpg, model_year, horsepower
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: weight, origin, model_year, cylinders -> name, acceleration, mpg, horsepower
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, horsepower, weight, cylinders -> acceleration, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, weight, model_year, cylinders -> name, acceleration, mpg, origin
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight, model_year, cylinders -> acceleration, mpg, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, cylinders -> name, horsepower, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, horsepower, cylinders -> name, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg, cylinders -> horsepower, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year, cylinders -> name, horsepower, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, horsepower, origin, cylinders -> name, mpg, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, cylinders -> horsepower, mpg, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year, cylinders -> name, horsepower, mpg, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, horsepower, cylinders -> mpg, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, horsepower, model_year, cylinders -> name, mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year, cylinders -> horsepower, mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, mpg, origin, cylinders -> name, acceleration, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, cylinders -> acceleration, horsepower, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, cylinders -> name, acceleration, horsepower, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, horsepower, mpg, cylinders -> acceleration, origin, model_year, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, mpg, model_year, cylinders -> name, acceleration, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year, cylinders -> acceleration, horsepower, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, horsepower, origin, cylinders -> acceleration, mpg, model_year, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: horsepower, origin, model_year, cylinders -> name, acceleration, mpg, weight
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year, cylinders -> acceleration, mpg, horsepower, weight
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, horsepower, model_year, cylinders -> acceleration, mpg, origin, weight
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, weight -> name, horsepower, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, horsepower, weight -> name, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg, weight -> horsepower, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year, weight -> name, horsepower, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, horsepower, origin, weight -> name, mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, weight -> horsepower, mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year, weight -> name, horsepower, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, horsepower, weight -> mpg, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, horsepower, model_year, weight -> name, mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year, weight -> horsepower, mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, mpg, origin, weight -> name, acceleration, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, weight -> acceleration, horsepower, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, weight -> name, acceleration, horsepower, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, horsepower, mpg, weight -> acceleration, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, mpg, model_year, weight -> name, acceleration, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year, weight -> acceleration, horsepower, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, horsepower, origin, weight -> acceleration, mpg, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: horsepower, origin, model_year, weight -> name, acceleration, mpg, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year, weight -> acceleration, mpg, horsepower, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, horsepower, model_year, weight -> acceleration, mpg, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin, horsepower -> name, weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, mpg, origin -> horsepower, weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, mpg, origin, model_year -> name, horsepower, weight, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, mpg, horsepower -> weight, origin, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year, horsepower -> name, weight, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg, model_year -> horsepower, weight, origin, cylinders
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, horsepower -> weight, model_year, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year, horsepower -> name, weight, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin, model_year -> horsepower, weight, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, acceleration, model_year, horsepower -> weight, origin, cylinders, mpg
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin, horsepower -> acceleration, weight, model_year, cylinders
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year, horsepower -> name, acceleration, weight, cylinders
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# ...
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, weight -> cylinders, acceleration, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: horsepower, origin, weight -> cylinders, acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: origin, weight, displacement -> cylinders, acceleration, mpg, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, weight -> cylinders, acceleration, mpg, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, weight -> cylinders, acceleration, mpg, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower, weight, displacement -> cylinders, acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, horsepower, weight -> cylinders, acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: horsepower, model_year, weight -> cylinders, acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight, displacement -> cylinders, acceleration, mpg, origin, horsepower, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, weight, displacement -> cylinders, acceleration, mpg, origin, horsepower, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year, weight -> cylinders, acceleration, mpg, origin, horsepower, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, origin -> weight, cylinders, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, horsepower -> weight, cylinders, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, mpg, displacement -> weight, cylinders, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, mpg -> weight, cylinders, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, mpg, model_year -> weight, cylinders, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin, horsepower -> weight, cylinders, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, origin, displacement -> weight, cylinders, mpg, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, acceleration, origin -> weight, cylinders, mpg, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: acceleration, origin, model_year -> weight, cylinders, mpg, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, horsepower, displacement -> weight, cylinders, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, horsepower -> weight, cylinders, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, horsepower -> weight, cylinders, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, displacement -> weight, cylinders, mpg, origin, horsepower, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year, displacement -> weight, cylinders, mpg, origin, horsepower, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration, model_year -> weight, cylinders, mpg, origin, horsepower, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, origin, horsepower -> weight, cylinders, acceleration, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, origin, displacement -> weight, cylinders, acceleration, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, mpg, origin -> weight, cylinders, acceleration, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: mpg, origin, model_year -> weight, cylinders, acceleration, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, horsepower, displacement -> weight, cylinders, acceleration, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, horsepower -> weight, cylinders, acceleration, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, horsepower -> weight, cylinders, acceleration, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, displacement -> weight, cylinders, acceleration, origin, horsepower, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year, displacement -> weight, cylinders, acceleration, origin, horsepower, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg, model_year -> weight, cylinders, acceleration, origin, horsepower, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: origin, horsepower, displacement -> weight, cylinders, acceleration, mpg, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, horsepower -> weight, cylinders, acceleration, mpg, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, horsepower -> weight, cylinders, acceleration, mpg, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, displacement -> weight, cylinders, acceleration, mpg, horsepower, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year, displacement -> weight, cylinders, acceleration, mpg, horsepower, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin, model_year -> weight, cylinders, acceleration, mpg, horsepower, displacement
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: name, horsepower, displacement -> weight, cylinders, acceleration, mpg, origin, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, horsepower, displacement -> weight, cylinders, acceleration, mpg, origin, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year, horsepower -> weight, cylinders, acceleration, mpg, origin, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: name, model_year, displacement -> weight, cylinders, acceleration, mpg, origin, horsepower
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: weight, cylinders -> acceleration, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, cylinders -> weight, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, cylinders -> weight, acceleration, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, cylinders -> weight, acceleration, mpg, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower, cylinders -> weight, acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: cylinders, displacement -> weight, acceleration, mpg, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, cylinders -> weight, acceleration, mpg, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, cylinders -> weight, acceleration, mpg, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, weight -> cylinders, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, weight -> cylinders, acceleration, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, weight -> cylinders, acceleration, mpg, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower, weight -> cylinders, acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight, displacement -> cylinders, acceleration, mpg, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, weight -> cylinders, acceleration, mpg, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, weight -> cylinders, acceleration, mpg, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, mpg -> weight, cylinders, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, origin -> weight, cylinders, mpg, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: acceleration, horsepower -> weight, cylinders, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration, displacement -> weight, cylinders, mpg, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, acceleration -> weight, cylinders, mpg, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: acceleration, model_year -> weight, cylinders, mpg, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, origin -> weight, cylinders, acceleration, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: mpg, horsepower -> weight, cylinders, acceleration, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg, displacement -> weight, cylinders, acceleration, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, mpg -> weight, cylinders, acceleration, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: mpg, model_year -> weight, cylinders, acceleration, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin, horsepower -> weight, cylinders, acceleration, mpg, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: origin, displacement -> weight, cylinders, acceleration, mpg, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: name, origin -> weight, cylinders, acceleration, mpg, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 1.0, Lift: 1.0
#
# Rule: origin, model_year -> weight, cylinders, acceleration, mpg, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower, displacement -> weight, cylinders, acceleration, mpg, origin, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, horsepower -> weight, cylinders, acceleration, mpg, origin, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, horsepower -> weight, cylinders, acceleration, mpg, origin, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, displacement -> weight, cylinders, acceleration, mpg, origin, horsepower, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year, displacement -> weight, cylinders, acceleration, mpg, origin, horsepower, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name, model_year -> weight, cylinders, acceleration, mpg, origin, horsepower, displacement
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: cylinders -> weight, acceleration, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: weight -> cylinders, acceleration, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: acceleration -> cylinders, weight, mpg, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: mpg -> cylinders, weight, acceleration, origin, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: origin -> cylinders, weight, acceleration, mpg, horsepower, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.9969135802469136, Lift: 0.9994632313472893
#
# Rule: horsepower -> cylinders, weight, acceleration, mpg, origin, displacement, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: displacement -> cylinders, weight, acceleration, mpg, origin, horsepower, name, model_year
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
#
# Rule: name -> cylinders, weight, acceleration, mpg, origin, horsepower, displacement, model_year
# Support: 0.8239795918367347, Confidence: 0.8260869565217391, Lift: 0.9994632313472893
#
# Rule: model_year -> cylinders, weight, acceleration, mpg, origin, horsepower, displacement, name
# Support: 0.8239795918367347, Confidence: 0.8239795918367347, Lift: 1.0
